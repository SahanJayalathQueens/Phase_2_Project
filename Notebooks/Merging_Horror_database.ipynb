# %%
import pandas as pd
import sqlite3

df  = pd.read_csv('TMDB_Horror_Data.csv')
df2 = pd.read_csv('TMDB_Horror_Data_p2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-95258d97d045> in <module>
#       2 import sqlite3
#       3
# ----> 4 df  = pd.read_csv('TMDB_Horror_Data.csv')
#       5 df2 = pd.read_csv('TMDB_Horror_Data_p2.csv')
#
# ...

# %%
df
# Out:
#        Unnamed: 0      ID                                    Title  \
# 0               0    4232                                   Scream
# 1               1    8078                       Alien Resurrection
# 2               2    1813                     The Devil's Advocate
# 3               3    4233                                 Scream 2
# 4               4  223286                          The Haunted Sea
# ...           ...     ...                                      ...
# 28656       28656  889107                     Fire on the Mountain
# 28657       28657  863593                                   Creaks
# 28658       28658  823356  Piotrek trzynastego 3: Dziecku rozmaryn
# 28659       28659  796734                        Rise of the Mummy
# 28660       28660  700705                 Sometimes She Comes Back
#
#       Release Date  Popularity  Vote Average  Vote Count    Budget    Revenue  \
# 0       1996-12-20      82.760         7.421        6841  14000000  173046663
# ...

# %%
df2
# Out:
#        Unnamed: 0       ID                                   Title  \
# 0               0   630240                                  Titane
# 1               1   630586                              Wrong Turn
# 2               2   423108  The Conjuring: The Devil Made Me Do It
# 3               3   520763                   A Quiet Place Part II
# 4               4   602223                       The Forever Purge
# ...           ...      ...                                     ...
# 14761       14761  1363525                                Karkhanu
# 14762       14762  1363470                          The Red Market
# 14763       14763  1363412                           The Days Left
# 14764       14764  1289034                     The Backseat Killer
# 14765       14765  1289018                        Black Magic Baby
#
#       Release Date  Popularity  Vote Average  Vote Count    Budget    Revenue  \
# 0       2021-07-14     118.003         6.400        1405   6600000    4982335
# ...

# %%
nu_df = pd.concat([df, df2], axis=0, ignore_index=True)

# %%
nu_df
# Out:
#        Unnamed: 0       ID                 Title Release Date  Popularity  \
# 0               0     4232                Scream   1996-12-20      82.760
# 1               1     8078    Alien Resurrection   1997-11-12      47.155
# 2               2     1813  The Devil's Advocate   1997-10-17      45.561
# 3               3     4233              Scream 2   1997-12-12      35.347
# 4               4   223286       The Haunted Sea   1997-01-01      34.618
# ...           ...      ...                   ...          ...         ...
# 43422       14761  1363525              Karkhanu   2024-08-02       0.000
# 43423       14762  1363470        The Red Market   2024-09-04       0.000
# 43424       14763  1363412         The Days Left   2024-02-17       0.000
# 43425       14764  1289034   The Backseat Killer   2024-05-09       0.000
# 43426       14765  1289018      Black Magic Baby   2024-07-03       0.000
#
#        Vote Average  Vote Count    Budget    Revenue  Runtime  \
# ...

# %%
import pandas as pd; 
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
nu_df
# Out:
#        Unnamed: 0       ID                 Title Release Date  Popularity  Vote Average  Vote Count    Budget    Revenue  Runtime                             Genres Original Language                               Production Companies               Production Countries                                           Overview                                            Tagline    Status                     Director
# 0               0     4232                Scream   1996-12-20      82.760         7.421        6841  14000000  173046663      112             Crime, Horror, Mystery                en               Dimension Films, Woods Entertainment           United States of America  A year after the murder of her mother, a teena...  Someone has taken their love of scary movies o...  Released                   Wes Craven
# ...

# %%
en_df = nu_df[(nu_df['Original Language'] == 'en')]

# %%
en_df
# Out:
#        Unnamed: 0       ID                 Title Release Date  Popularity  Vote Average  Vote Count    Budget    Revenue  Runtime                             Genres Original Language                               Production Companies               Production Countries                                           Overview                                            Tagline    Status                     Director
# 0               0     4232                Scream   1996-12-20      82.760         7.421        6841  14000000  173046663      112             Crime, Horror, Mystery                en               Dimension Films, Woods Entertainment           United States of America  A year after the murder of her mother, a teena...  Someone has taken their love of scary movies o...  Released                   Wes Craven
# ...

# %%
nu_df.value_counts('Production Companies')
# Out:
# Production Companies
# Amumo 98                                                         211
# Brain Damage Films                                                95
# The Asylum                                                        83
# At Entertainment Inc.                                             78
# LAMIA Project                                                     78
#                                                                 ...
# Oak Film Co., People People Media Co.                              1
# OZPIX Entertainment, Slaughter FX, Giddyup Films, Nexus Films      1
# OUTFIELD Productions                                               1
# OTS Films Inc.                                                     1
# "GREEN" Productions                                                1
# Length: 16843, dtype: int64

# %%
nu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43427 entries, 0 to 43426
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            43427 non-null  int64
#  1   ID                    43427 non-null  int64
#  2   Title                 43427 non-null  object
#  3   Release Date          43423 non-null  object
#  4   Popularity            43427 non-null  float64
#  5   Vote Average          43427 non-null  float64
#  6   Vote Count            43427 non-null  int64
#  7   Budget                43427 non-null  int64
#  8   Revenue               43427 non-null  int64
#  9   Runtime               43427 non-null  int64
#  10  Genres                43423 non-null  object
#  11  Original Language     43427 non-null  object
#  12  Production Companies  24174 non-null  object
#  13  Production Countries  32208 non-null  object
#  14  Overview              41190 non-null  object
# ...
