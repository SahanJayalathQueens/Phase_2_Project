# %%
import requests
import pandas as pd

api_key = '95408ea58dbcf11b6cfd9e44971ff7a4'

url = 'https://api.themoviedb.org/3/discover/movie'

params = {
    'api_key': api_key,
    'with_genres': '27',        # Genre ID for Horror
    'primary_release_date.gte': '1996-01-01',  # From Jan 1, 1996
    'primary_release_date.lte': '2020-12-31',  # Until Dec 31, 2020
    'language': 'en-US',        # Results in English
    'sort_by': 'popularity.desc',  # Sort by popularity
    'page': 1                   # Starting page
}


def get_all_movies(url, params):
    all_movies = []
    
    while True:
        response = requests.get(url, params=params)
        if response.status_code == 200:
            data = response.json()
            
  
            for movie in data['results']:
                movie_info = {
                    'Title': movie['title'],
                    'Release Date': movie['release_date'],
                    'Popularity': movie['popularity'],
                    'Vote Average': movie['vote_average'],
                    'Budget': movie['budget'],
                    'Revenue': movie['revenue']
                    #'Overview': movie['overview']
                }
                all_movies.append(movie_info)
            
     
            if params['page'] >= data['total_pages']:
                break  # Exit the loop if the last page is reached
            else:
                params['page'] += 1  # Go to the next page
        else:
            print(f"Error: {response.status_code}")
            break
    
    return all_movies

movies_list = get_all_movies(url, params)

movies_df = pd.DataFrame(movies_list)

print(movies_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-faa2615563d0> in <module>
#      49     return all_movies
#      50
# ---> 51 movies_list = get_all_movies(url, params)
#      52
#      53 movies_df = pd.DataFrame(movies_list)
#
# <ipython-input-16-faa2615563d0> in get_all_movies(url, params)
#      32                     'Popularity': movie['popularity'],
#      33                     'Vote Average': movie['vote_average'],
# ---> 34                     'Budget': movie['budget'],
#      35                     'Revenue': movie['revenue']
#      36                     #'Overview': movie['overview']
#
# KeyError: 'budget'

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         10000 non-null  object
#  1   Release Date  10000 non-null  object
#  2   Popularity    10000 non-null  float64
#  3   Vote Average  10000 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 312.6+ KB

# %%
movies_df
# Out:
#                                Title Release Date  Popularity  Vote Average
# 0                    Alien: Covenant   2017-05-09      96.586         6.138
# 1                     Train to Busan   2016-07-20      94.900         7.754
# 2                         Vassalord.   2013-03-15      93.932         5.500
# 3                    The Conjuring 2   2016-06-08      91.265         7.295
# 4                      The Conjuring   2013-07-18      90.387         7.543
# ...                              ...          ...         ...           ...
# 9995             Expelling the Demon   1999-06-19       1.312         7.000
# 9996                      Charismata   2017-11-04       1.312         4.700
# 9997   Wolf Tracer's Dinosaur Island   2004-01-12       1.312         3.200
# 9998  Her Name Was Torment II: Agony   2016-11-19       1.312         2.500
# 9999             Il mistero del lago   2009-01-07       1.312         6.500
#
# [10000 rows x 4 columns]

# %%
movies_df.to_csv('movies_df')

# %%
import requests
import pandas as pd

api_key = '95408ea58dbcf11b6cfd9e44971ff7a4'

url = 'https://api.themoviedb.org/3/discover/movie'

params = {
    'api_key': api_key,
    'with_genres': '27',        # Genre ID for Horror
    'primary_release_date.gte': '1996-01-01',  # From Jan 1, 1996
    'primary_release_date.lte': '2020-12-31',  # Until Dec 31, 2020
    'language': 'en-US',        # Results in English
    'sort_by': 'popularity.desc',  # Sort by popularity
    'page': 1                   # Starting page
}

def get_movie_details(movie_id, api_key):
    """
    Fetch detailed information for a specific movie.
    """
    url = f'https://api.themoviedb.org/3/movie/{movie_id}'
    params = {'api_key': api_key}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        return None

def get_all_movies(url, params, api_key):
    all_movies = []

    while True:
        response = requests.get(url, params=params)
        if response.status_code == 200:
            data = response.json()

            for movie in data['results']:
                # Fetch additional movie details
                movie_details = get_movie_details(movie['id'], api_key)
                if movie_details:
                    movie_info = {
                        'Title': movie['title'],
                        'Release Date': movie['release_date'],
                        'Popularity': movie['popularity'],
                        'Vote Average': movie['vote_average'],
                        'Budget': movie_details['budget'],
                        'Revenue': movie_details['revenue']
                    }
                    all_movies.append(movie_info)

            if params['page'] >= data['total_pages']:
                break  # Exit the loop if the last page is reached
            else:
                params['page'] += 1  # Go to the next page
        else:
            print(f"Error: {response.status_code}")
            break

    return all_movies

movies_list = get_all_movies(url, params, api_key)

movies_df_2 = pd.DataFrame(movies_list)

movies_df_2
# Out:
# Error: 400
#                                Title Release Date  Popularity  Vote Average  \
# 0                    Alien: Covenant   2017-05-09      96.586         6.138
# 1                     Train to Busan   2016-07-20      94.900         7.754
# 2                         Vassalord.   2013-03-15      93.932         5.500
# 3                    The Conjuring 2   2016-06-08      91.265         7.295
# 4                      The Conjuring   2013-07-18      90.387         7.543
# ...                              ...          ...         ...           ...
# 9995             Expelling the Demon   1999-06-19       1.312         7.000
# 9996                      Charismata   2017-11-04       1.312         4.700
# 9997   Wolf Tracer's Dinosaur Island   2004-01-12       1.312         3.200
# 9998  Her Name Was Torment II: Agony   2016-11-19       1.312         2.500
# 9999             Il mistero del lago   2009-01-07       1.312         6.500
#
#         Budget    Revenue
# 0     97000000  240891763
# 1      8500000   87547518
# 2            0          0
# 3     40000000  322811702
# 4     13000000  320415166
# ...        ...        ...
# 9995         0          0
# 9996         0          0
# 9997         0          0
# 9998      6000          0
# 9999         0          0
#
# [10000 rows x 6 columns]

# %%
movies_df.to_csv('movies_df_budget')

# %%
import requests
import pandas as pd
import time

api_key = '95408ea58dbcf11b6cfd9e44971ff7a4'

url = 'https://api.themoviedb.org/3/discover/movie'

params = {
    'api_key': api_key,
    'with_genres': '27',        # Genre ID for Horror
    'primary_release_date.gte': '1996-01-01',  # From Jan 1, 1996
    'primary_release_date.lte': '2020-12-31',  # Until Dec 31, 2020
    'language': 'en-US',        # Results in English
    'sort_by': 'popularity.desc',  # Sort by popularity
    'page': 1                   # Starting page
}

def get_movie_details(movie_id, api_key):
    """
    Fetch detailed information for a specific movie.
    """
    url = f'https://api.themoviedb.org/3/movie/{movie_id}'
    params = {'api_key': api_key}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching details for movie ID {movie_id}: {response.status_code}")
        return None

def get_all_movies(url, params, api_key):
    all_movies = []

    while True:
        response = requests.get(url, params=params)
        if response.status_code == 200:
            data = response.json()

            for movie in data['results']:
                # Fetch additional movie details
                movie_details = get_movie_details(movie['id'], api_key)
                if movie_details:
                    movie_info = {
                        'Title': movie['title'],
                        'Release Date': movie['release_date'],
                        'Popularity': movie['popularity'],
                        'Vote Average': movie['vote_average'],
                        'Budget': movie_details.get('budget', None),
                        'Revenue': movie_details.get('revenue', None)
                    }
                    all_movies.append(movie_info)

            # Check if we've reached the last page
            if params['page'] >= data['total_pages']:
                break  # Exit the loop if the last page is reached
            else:
                params['page'] += 1  # Go to the next page
                time.sleep(0.1)  # Small delay to avoid hitting rate limits
        else:
            # Log the error status code
            print(f"Error: {response.status_code}")
            if response.status_code == 429:  # Too Many Requests
                print("Rate limit exceeded. Waiting for 15 seconds before retrying...")
                time.sleep(15)
            else:
                break

    return all_movies

movies_list = get_all_movies(url, params, api_key)

movies_df_3 = pd.DataFrame(movies_list)

movies_df3
# Out:
# Error: 400
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8b05ac856d86> in <module>
#      74 movies_df_3 = pd.DataFrame(movies_list)
#      75
# ---> 76 movies_df3
#
# NameError: name 'movies_df3' is not defined

# %%
import requests
import pandas as pd
import time

api_key = '95408ea58dbcf11b6cfd9e44971ff7a4'
base_url = 'https://api.themoviedb.org/3/discover/movie'

params = {
    'api_key': api_key,
    'with_genres': '27',        # Genre ID for Horror
    'primary_release_date.gte': '1996-01-01',  # From Jan 1, 1996
    'primary_release_date.lte': '2020-12-31',  # Until Dec 31, 2020
    'language': 'en-US',        # Results in English
    'sort_by': 'popularity.desc',  # Sort by popularity
    'page': 1                   # Starting page
}

def get_movie_details(movie_id, api_key):
    """
    Fetch detailed information for a specific movie.
    """
    url = f'https://api.themoviedb.org/3/movie/{movie_id}'
    params = {'api_key': api_key}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching details for movie ID {movie_id}: {response.status_code}")
        return None

def get_all_movies(base_url, params, api_key):
    all_movies = []
    total_pages = 0

    # Get total pages
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        total_pages = data['total_pages']
    else:
        print(f"Error fetching total pages: {response.status_code}, {response.text}")
        return

    # Fetch data in chunks of 500 pages
    for start_page in range(1, total_pages + 1, 500):
        end_page = min(start_page + 499, total_pages)
        for page in range(start_page, end_page + 1):
            params['page'] = page
            response = requests.get(base_url, params=params)
            if response.status_code == 200:
                data = response.json()

                for movie in data['results']:
                    # Fetch additional movie details
                    movie_details = get_movie_details(movie['id'], api_key)
                    if movie_details:
                        movie_info = {
                            'ID': movie_details.get('id', None),
                            'Title': movie_details.get('title', None),
                            'Release Date': movie_details.get('release_date', None),
                            'Popularity': movie_details.get('popularity', None),
                            'Vote Average': movie_details.get('vote_average', None),
                            'Vote Count': movie_details.get('vote_count', None),
                            'Budget': movie_details.get('budget', None),
                            'Revenue': movie_details.get('revenue', None),
                            'Runtime': movie_details.get('runtime', None),
                            'Genres': ', '.join([genre['name'] for genre in movie_details.get('genres', [])]),
                            'Original Language': movie_details.get('original_language', None),
                            'Production Companies': ', '.join([company['name'] for company in movie_details.get('production_companies', [])]),
                            'Production Countries': ', '.join([country['name'] for country in movie_details.get('production_countries', [])]),
                            'Overview': movie_details.get('overview', None),
                            'Tagline': movie_details.get('tagline', None),
                            'Status': movie_details.get('status', None)
                        }
                        all_movies.append(movie_info)

                time.sleep(0.1)  # Small delay to avoid hitting rate limits
            else:
                # Log the error status code and response text
                print(f"Error: {response.status_code}, {response.text}")
                if response.status_code == 429:  # Too Many Requests
                    print("Rate limit exceeded. Waiting for 15 seconds before retrying...")
                    time.sleep(15)
                else:
                    break

    return all_movies

movies_list = get_all_movies(base_url, params, api_key)

movies_df_3 = pd.DataFrame(movies_list)

movies_df_3
# Out:
# Error: 400
#                                Title Release Date  Popularity  Vote Average  \
# 0                    Alien: Covenant   2017-05-09      96.586         6.138
# 1                     Train to Busan   2016-07-20      94.900         7.754
# 2                         Vassalord.   2013-03-15      93.932         5.500
# 3                    The Conjuring 2   2016-06-08      91.265         7.295
# 4                      The Conjuring   2013-07-18      90.387         7.543
# ...                              ...          ...         ...           ...
# 9995             Expelling the Demon   1999-06-19       1.312         7.000
# 9996                      Charismata   2017-11-04       1.312         4.700
# 9997   Wolf Tracer's Dinosaur Island   2004-01-12       1.312         3.200
# 9998  Her Name Was Torment II: Agony   2016-11-19       1.312         2.500
# 9999             Il mistero del lago   2009-01-07       1.312         6.500
#
#         Budget    Revenue
# 0     97000000  240891763
# 1      8500000   87547518
# 2            0          0
# 3     40000000  322811702
# 4     13000000  320415166
# ...        ...        ...
# 9995         0          0
# 9996         0          0
# 9997         0          0
# 9998      6000          0
# 9999         0          0
#
# [10000 rows x 6 columns]

# %%
api_key = '95408ea58dbcf11b6cfd9e44971ff7a4'
base_url = 'https://api.themoviedb.org/3/discover/movie'

params = {
    'api_key': api_key,
    'with_genres': '27',        # Genre ID for Horror
    'primary_release_date.gte': '1996-01-01',  # From Jan 1, 1996
    'primary_release_date.lte': '2020-12-31',  # Until Dec 31, 2020
    'language': 'en-US',        # Results in English
    'sort_by': 'popularity.desc',  # Sort by popularity
    'page': 1                   # Starting page
}

def get_movie_details(movie_id, api_key):
    """
    Fetch detailed information for a specific movie.
    """
    url = f'https://api.themoviedb.org/3/movie/{movie_id}'
    params = {'api_key': api_key}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching details for movie ID {movie_id}: {response.status_code}")
        return None

def get_all_movies(base_url, params, api_key):
    all_movies = []
    total_pages = 0

    # Get total pages
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        total_pages = data['total_pages']
    else:
        print(f"Error fetching total pages: {response.status_code}, {response.text}")
        return

    # Fetch data in chunks of 500 pages
    for start_page in range(1, total_pages + 1, 500):
        end_page = min(start_page + 499, total_pages)
        for page in range(start_page, end_page + 1):
            params['page'] = page
            response = requests.get(base_url, params=params)
            if response.status_code == 200:
                data = response.json()

                for movie in data['results']:
                    # Fetch additional movie details
                    movie_details = get_movie_details(movie['id'], api_key)
                    if movie_details:
                        movie_info = {
                            'ID': movie_details.get('id', None),
                            'Title': movie_details.get('title', None),
                            'Release Date': movie_details.get('release_date', None),
                            'Popularity': movie_details.get('popularity', None),
                            'Vote Average': movie_details.get('vote_average', None),
                            'Vote Count': movie_details.get('vote_count', None),
                            'Budget': movie_details.get('budget', None),
                            'Revenue': movie_details.get('revenue', None),
                            'Runtime': movie_details.get('runtime', None),
                            'Genres': ', '.join([genre['name'] for genre in movie_details.get('genres', [])]),
                            'Original Language': movie_details.get('original_language', None),
                            'Production Companies': ', '.join([company['name'] for company in movie_details.get('production_companies', [])]),
                            'Production Countries': ', '.join([country['name'] for country in movie_details.get('production_countries', [])]),
                            'Overview': movie_details.get('overview', None),
                            'Tagline': movie_details.get('tagline', None),
                            'Status': movie_details.get('status', None)
                        }
                        all_movies.append(movie_info)

                time.sleep(0.1)  # Small delay to avoid hitting rate limits
            else:
                # Log the error status code and response text
                print(f"Error: {response.status_code}, {response.text}")
                if response.status_code == 429:  # Too Many Requests
                    print("Rate limit exceeded. Waiting for 15 seconds before retrying...")
                    time.sleep(15)
                else:
                    break

    return all_movies

movies_list = get_all_movies(base_url, params, api_key)

movies_df_3 = pd.DataFrame(movies_list)

movies_df_3
# Out:
# Error: 400, {"success":false,"status_code":22,"status_message":"Invalid page: Pages start at 1 and max at 500. They are expected to be an integer."}
# Error: 400, {"success":false,"status_code":22,"status_message":"Invalid page: Pages start at 1 and max at 500. They are expected to be an integer."}
#           ID                           Title Release Date  Popularity  \
# 0     126889                 Alien: Covenant   2017-05-09      96.586
# 1     396535                  Train to Busan   2016-07-20      94.900
# 2     444483                      Vassalord.   2013-03-15      93.932
# 3     259693                 The Conjuring 2   2016-06-08      91.265
# 4     138843                   The Conjuring   2013-07-18      90.387
# ...      ...                             ...          ...         ...
# 9995  530104             Expelling the Demon   1999-06-19       1.312
# 9996  478741                      Charismata   2017-11-04       1.312
# 9997  430981   Wolf Tracer's Dinosaur Island   2004-01-12       1.312
# 9998  341963  Her Name Was Torment II: Agony   2016-11-19       1.312
# 9999  305634             Il mistero del lago   2009-01-07       1.312
#
#       Vote Average  Vote Count    Budget    Revenue  Runtime  \
# 0            6.138        8507  97000000  240891763      122
# 1            7.754        7313   8500000   87547518      118
# 2            5.500          14         0          0       28
# 3            7.295        8278  40000000  322811702      134
# 4            7.543       11391  13000000  320415166      113
# ...            ...         ...       ...        ...      ...
# 9995         7.000           1         0          0        5
# 9996         4.700          21         0          0      100
# 9997         3.200           4         0          0       45
# 9998         2.500           2      6000          0       56
# 9999         6.500           5         0          0       90
#
#                                                  Genres Original Language  \
# 0                     Science Fiction, Horror, Thriller                en
# 1                   Horror, Thriller, Action, Adventure                ko
# 2     Animation, Action, Mystery, Fantasy, Comedy, D...                ja
# 3                                                Horror                en
# 4                                      Horror, Thriller                en
# ...                                                 ...               ...
# 9995                                  Animation, Horror                en
# 9996                                             Horror                en
# 9997  TV Movie, Horror, Adventure, Family, Fantasy, ...                en
# 9998                                             Horror                en
# 9999                   Horror, Mystery, Drama, TV Movie                it
#
#                                    Production Companies  \
# 0     20th Century Fox, Brandywine Productions, Scot...
# 1              Next Entertainment World, RedPeter Films
# 2                                        Production I.G
# 3     New Line Cinema, The Safran Company, Atomic Mo...
# 4     Evergreen Media Group, New Line Cinema, The Sa...
# ...                                                 ...
# 9995
# 9996                Hydra Films RKM, Loose Canons Films
# 9997                            Wolf Tracer Studios Inc
# 9998                           Dustin Mills Productions
# 9999  Leader Cinematografica, RTI - Reti Televisive ...
#
#           Production Countries  \
# 0     United States of America
# 1                  South Korea
# 2                        Japan
# 3     United States of America
# 4     United States of America
# ...                        ...
# 9995            United Kingdom
# 9996            United Kingdom
# 9997  United States of America
# 9998  United States of America
# 9999                     Italy
#
#                                                Overview  \
# 0     The crew of the colony ship Covenant, bound fo...
# 1     When a zombie virus pushes Korea into a state ...
# 2     Charley, a cyborg vampire who does the Vatican...
# 3     Lorraine and Ed Warren travel to north London ...
# 4     Paranormal investigators Ed and Lorraine Warre...
# ...                                                 ...
# 9995  The story takes place in a bedroom where, foll...
# 9996  As a rookie detective struggling to find accep...
# 9997  Deep sea fishing expedition comes to a halt wh...
# 9998  Her Name Was Torment II: Agony is a bigger, me...
# 9999  The film, based on the novel "The Turn of the ...
#
#                                                 Tagline    Status
# 0                  The path to paradise begins in hell.  Released
# 1                        Life-or-death survival begins.  Released
# 2                                                        Released
# 3     The next true story from the case files of Ed ...  Released
# 4           Based on the true case files of the Warrens  Released
# ...                                                 ...       ...
# 9995                                                     Released
# 9996                                   Face Your Demons  Released
# 9997                        Extinct? Who's extinct now?  Released
# 9998                                                     Released
# 9999                                                     Released
#
# [10000 rows x 16 columns]

# %%
import requests
import pandas as pd
import time
from datetime import datetime, timedelta

api_key = '95408ea58dbcf11b6cfd9e44971ff7a4'
base_url = 'https://api.themoviedb.org/3/discover/movie'

def get_movie_details(movie_id, api_key):
    """
    Fetch detailed information for a specific movie.
    """
    url = f'https://api.themoviedb.org/3/movie/{movie_id}'
    params = {'api_key': api_key}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching details for movie ID {movie_id}: {response.status_code}")
        return None

def get_movie_credits(movie_id, api_key):
    """
    Fetch credits information for a specific movie.
    """
    url = f'https://api.themoviedb.org/3/movie/{movie_id}/credits'
    params = {'api_key': api_key}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching credits for movie ID {movie_id}: {response.status_code}")
        return None

def get_all_movies(base_url, params, api_key):
    all_movies = []

    while True:
        response = requests.get(base_url, params=params)
        if response.status_code == 200:
            data = response.json()

            for movie in data['results']:
                # Fetch additional movie details
                movie_details = get_movie_details(movie['id'], api_key)
                if movie_details:
                    # Fetch credits to get the director's name
                    movie_credits = get_movie_credits(movie['id'], api_key)
                    director = None
                    if movie_credits:
                        for crew_member in movie_credits['crew']:
                            if crew_member['job'] == 'Director':
                                director = crew_member['name']
                                break

                    movie_info = {
                        'ID': movie_details.get('id', None),
                        'Title': movie_details.get('title', None),
                        'Release Date': movie_details.get('release_date', None),
                        'Popularity': movie_details.get('popularity', None),
                        'Vote Average': movie_details.get('vote_average', None),
                        'Vote Count': movie_details.get('vote_count', None),
                        'Budget': movie_details.get('budget', None),
                        'Revenue': movie_details.get('revenue', None),
                        'Runtime': movie_details.get('runtime', None),
                        'Genres': ', '.join([genre['name'] for genre in movie_details.get('genres', [])]),
                        'Original Language': movie_details.get('original_language', None),
                        'Production Companies': ', '.join([company['name'] for company in movie_details.get('production_companies', [])]),
                        'Production Countries': ', '.join([country['name'] for country in movie_details.get('production_countries', [])]),
                        'Overview': movie_details.get('overview', None),
                        'Tagline': movie_details.get('tagline', None),
                        'Status': movie_details.get('status', None),
                        'Director': director
                    }
                    all_movies.append(movie_info)

            # Check if we've reached the last page
            if params['page'] >= data['total_pages']:
                break  # Exit the loop if the last page is reached
            else:
                params['page'] += 1  # Go to the next page
                time.sleep(0.1)  # Small delay to avoid hitting rate limits
        else:
            # Log the error status code
            print(f"Error: {response.status_code}, {response.text}")
            if response.status_code == 429:  # Too Many Requests
                print("Rate limit exceeded. Waiting for 15 seconds before retrying...")
                time.sleep(15)
            else:
                break

    return all_movies

# Function to split date range into smaller segments
def date_range_split(start_date, end_date, delta):
    current_date = start_date
    while current_date < end_date:
        next_date = current_date + delta
        yield current_date, min(next_date, end_date)
        current_date = next_date

# Set the overall date range and desired segment size
start_year = 1996
end_year = 2020
start_date = datetime(start_year, 1, 1)
end_date = datetime(end_year, 12, 31)
segment_size = timedelta(days=365 * 2)  # Two-year segments

all_movies_combined = []

for segment_start, segment_end in date_range_split(start_date, end_date, segment_size):
    print(f"Fetching data from {segment_start.date()} to {segment_end.date()}")
    params['primary_release_date.gte'] = segment_start.date().isoformat()
    params['primary_release_date.lte'] = segment_end.date().isoformat()
    params['page'] = 1
    segment_movies = get_all_movies(base_url, params, api_key)
    all_movies_combined.extend(segment_movies)

# Save intermediate results to a CSV file to avoid data loss
movies_df = pd.DataFrame(all_movies_combined)
movies_df.to_csv('tmdb_movies.csv', index=False)

print(movies_df)
# Out:
# Fetching data from 1996-01-01 to 1997-12-31
# Fetching data from 1997-12-31 to 1999-12-31
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-1053192f58f3> in <module>
#     116     params['primary_release_date.lte'] = segment_end.date().isoformat()
#     117     params['page'] = 1
# --> 118     segment_movies = get_all_movies(base_url, params, api_key)
#     119     all_movies_combined.extend(segment_movies)
#     120
#
# <ipython-input-23-1053192f58f3> in get_all_movies(base_url, params, api_key)
#      45             for movie in data['results']:
#      46                 # Fetch additional movie details
# ---> 47                 movie_details = get_movie_details(movie['id'], api_key)
#      48                 if movie_details:
#      49                     # Fetch credits to get the director's name
#
# <ipython-input-23-1053192f58f3> in get_movie_details(movie_id, api_key)
#      13     url = f'https://api.themoviedb.org/3/movie/{movie_id}'
#      14     params = {'api_key': api_key}
# ---> 15     response = requests.get(url, params=params)
#      16
#      17     if response.status_code == 200:
#
# ~\.conda\envs\learn-env\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\.conda\envs\learn-env\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\.conda\envs\learn-env\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\.conda\envs\learn-env\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\.conda\envs\learn-env\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\.conda\envs\learn-env\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\.conda\envs\learn-env\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379         # Trigger any extra validation we need to do.
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#     383             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\.conda\envs\learn-env\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     976         # Force connect early to allow us to validate the connection.
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#     980         if not conn.is_verified:
#
# ~\.conda\envs\learn-env\lib\site-packages\urllib3\connection.py in connect(self)
#     360             context.load_default_certs()
#     361
# --> 362         self.sock = ssl_wrap_socket(
#     363             sock=conn,
#     364             keyfile=self.key_file,
#
# ~\.conda\envs\learn-env\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     382     ) or IS_SECURETRANSPORT:
#     383         if HAS_SNI and server_hostname is not None:
# --> 384             return context.wrap_socket(sock, server_hostname=server_hostname)
#     385
#     386         warnings.warn(
#
# ~\.conda\envs\learn-env\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# ~\.conda\envs\learn-env\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# ~\.conda\envs\learn-env\lib\ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
import requests
import pandas as pd
import time
from datetime import datetime, timedelta

api_key = '95408ea58dbcf11b6cfd9e44971ff7a4'
base_url = 'https://api.themoviedb.org/3/discover/movie'

params = {
    'api_key': api_key,
    'with_genres': '27',  # Genre ID for Horror
    'language': 'en-US',  # Results in English
    'sort_by': 'popularity.desc',  # Sort by popularity
    'page': 1  # Starting page
}

def get_movie_details(movie_id, api_key):
    """
    Fetch detailed information for a specific movie.
    """
    url = f'https://api.themoviedb.org/3/movie/{movie_id}'
    params = {'api_key': api_key}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching details for movie ID {movie_id}: {response.status_code}")
        return None

def get_movie_credits(movie_id, api_key):
    """
    Fetch credits information for a specific movie.
    """
    url = f'https://api.themoviedb.org/3/movie/{movie_id}/credits'
    params = {'api_key': api_key}
    response = requests.get(url, params=params)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching credits for movie ID {movie_id}: {response.status_code}")
        return None

def get_all_movies(base_url, params, api_key):
    all_movies = []
    total_pages = 0

    # Get total pages
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        total_pages = data['total_pages']
    else:
        print(f"Error fetching total pages: {response.status_code}, {response.text}")
        return

    # Fetch data in chunks of 500 pages
    for start_page in range(1, total_pages + 1, 500):
        end_page = min(start_page + 499, total_pages)
        for page in range(start_page, end_page + 1):
            params['page'] = page
            response = requests.get(base_url, params=params)
            if response.status_code == 200:
                data = response.json()

                for movie in data['results']:
                    # Fetch additional movie details
                    movie_details = get_movie_details(movie['id'], api_key)
                    if movie_details:
                        # Fetch credits to get the director's name
                        movie_credits = get_movie_credits(movie['id'], api_key)
                        director = None
                        if movie_credits:
                            for crew_member in movie_credits['crew']:
                                if crew_member['job'] == 'Director':
                                    director = crew_member['name']
                                    break

                        movie_info = {
                            'ID': movie_details.get('id', None),
                            'Title': movie_details.get('title', None),
                            'Release Date': movie_details.get('release_date', None),
                            'Popularity': movie_details.get('popularity', None),
                            'Vote Average': movie_details.get('vote_average', None),
                            'Vote Count': movie_details.get('vote_count', None),
                            'Budget': movie_details.get('budget', None),
                            'Revenue': movie_details.get('revenue', None),
                            'Runtime': movie_details.get('runtime', None),
                            'Genres': ', '.join([genre['name'] for genre in movie_details.get('genres', [])]),
                            'Original Language': movie_details.get('original_language', None),
                            'Production Companies': ', '.join([company['name'] for company in movie_details.get('production_companies', [])]),
                            'Production Countries': ', '.join([country['name'] for country in movie_details.get('production_countries', [])]),
                            'Overview': movie_details.get('overview', None),
                            'Tagline': movie_details.get('tagline', None),
                            'Status': movie_details.get('status', None),
                            'Director': director
                        }
                        all_movies.append(movie_info)

                time.sleep(0.1)  # Small delay to avoid hitting rate limits
            else:
                # Log the error status code and response text
                print(f"Error: {response.status_code}, {response.text}")
                if response.status_code == 429:  # Too Many Requests
                    print("Rate limit exceeded. Waiting for 15 seconds before retrying...")
                    time.sleep(15)
                else:
                    break

    return all_movies

# Function to split date range into smaller segments
def date_range_split(start_date, end_date, delta):
    current_date = start_date
    while current_date < end_date:
        next_date = current_date + delta
        yield current_date, min(next_date, end_date)
        current_date = next_date

# Set the overall date range and desired segment size
start_year = 1996
end_year = 2020
start_date = datetime(start_year, 1, 1)
end_date = datetime(end_year, 12, 31)
segment_size = timedelta(days=365 * 2)  # Two-year segments

all_movies_combined = []

for segment_start, segment_end in date_range_split(start_date, end_date, segment_size):
    print(f"Fetching data from {segment_start.date()} to {segment_end.date()}")
    params['primary_release_date.gte'] = segment_start.date().isoformat()
    params['primary_release_date.lte'] = segment_end.date().isoformat()
    params['page'] = 1
    segment_movies = get_all_movies(base_url, params, api_key)
    all_movies_combined.extend(segment_movies)

# Save intermediate results to a CSV file to avoid data loss
movies_df = pd.DataFrame(all_movies_combined)
movies_df.to_csv('tmdb_movies.csv', index=False)

print(movies_df)
# Out:
# Fetching data from 1996-01-01 to 1997-12-31
# Fetching data from 1997-12-31 to 1999-12-31
# Fetching data from 1999-12-31 to 2001-12-30
# Fetching data from 2001-12-30 to 2003-12-30
# Fetching data from 2003-12-30 to 2005-12-29
# Fetching data from 2005-12-29 to 2007-12-29
# Fetching data from 2007-12-29 to 2009-12-28
# Fetching data from 2009-12-28 to 2011-12-28
# Fetching data from 2011-12-28 to 2013-12-27
# Fetching data from 2013-12-27 to 2015-12-27
# Fetching data from 2015-12-27 to 2017-12-26
# Fetching data from 2017-12-26 to 2019-12-26
# Fetching data from 2019-12-26 to 2020-12-31
#             ID                                    Title Release Date  \
# 0         4232                                   Scream   1996-12-20
# 1         1813                     The Devil's Advocate   1997-10-17
# 2         8078                       Alien Resurrection   1997-11-12
# 3         4233                                 Scream 2   1997-12-12
# 4         9360                                 Anaconda   1997-04-11
# ...        ...                                      ...          ...
# 28657   863593                                   Creaks   2020-06-18
# 28658   823356  Piotrek trzynastego 3: Dziecku rozmaryn   2020-04-22
# 28659   796734                        Rise of the Mummy   2020-04-03
# 28660   700705                 Sometimes She Comes Back   2020-08-05
# 28661  1362981                         Milla: The Movie   2020-10-01
#
#        Popularity  Vote Average  Vote Count    Budget    Revenue  Runtime  \
# 0          81.736         7.421        6838  14000000  173046663      112
# 1          55.402         7.467        5891  57000000  153000000      144
# 2          46.027         6.152        4840  70000000  162000000      109
# 3          43.971         6.493        4074  24000000  172363301      120
# 4          32.929         5.198        2443  45000000  136900000       89
# ...           ...           ...         ...       ...        ...      ...
# 28657       0.001         0.000           0         0          0        5
# 28658       0.001         0.000           0         0          0       83
# 28659       0.001         0.000           0         0          0       87
# 28660       0.001         0.000           0         0          0        7
# 28661       0.000         9.000           1         0          0       98
#
#                                  Genres Original Language  \
# 0                Crime, Horror, Mystery                en
# 1      Drama, Mystery, Thriller, Horror                en
# 2       Science Fiction, Horror, Action                en
# 3                       Horror, Mystery                en
# 4           Adventure, Horror, Thriller                en
# ...                                 ...               ...
# 28657                            Horror                en
# 28658                    Horror, Comedy                pl
# 28659                            Horror                en
# 28660                   Horror, Fantasy                pt
# 28661           Thriller, Drama, Horror                en
#
#                                     Production Companies  \
# 0                   Dimension Films, Woods Entertainment
# 1      Monarchy Enterprises B.V., Regency Enterprises...
# 2               20th Century Fox, Brandywine Productions
# 3      Dimension Films, Konrad Pictures, Craven-Madda...
# 4      St. Tropez Films, Cinema Line Film Corporation...
# ...                                                  ...
# 28657
# 28658  Muflon Pictures, Exd' Art - Obrazy bez granic,...
# 28659
# 28660                             Suco Excêntrico Filmes
# 28661                                             21film
#
#                          Production Countries  \
# 0                    United States of America
# 1           Germany, United States of America
# 2            United States of America, France
# 3                    United States of America
# 4      Brazil, Peru, United States of America
# ...                                       ...
# 28657
# 28658                                  Poland
# 28659
# 28660                                  Brazil
# 28661
#
#                                                 Overview  \
# 0      A year after the murder of her mother, a teena...
# 1      Aspiring Florida defense lawyer Kevin Lomax ac...
# 2      Two hundred years after Lt. Ripley died, a gro...
# 3      Two years after the first series of murders, a...
# 4      A "National Geographic" film crew is taken hos...
# ...                                                  ...
# 28657  Do you still believe in monsters in your close...
# 28658  The third part of the American horror movie pa...
# 28659  A group of friends seize the opportunity to le...
# 28660  Erica tries to distract herself in front of th...
# 28661  "THE WORST NIGHTMARE RESTS WHERE NOT EXPECTED"...
#
#                                                  Tagline    Status  \
# 0      Someone has taken their love of scary movies o...  Released
# 1      The newest attorney at the world's most powerf...  Released
# 2                                 It's already too late.  Released
# 3      Someone has taken their love of sequels one st...  Released
# 4              When you can't breathe, you can't scream.  Released
# ...                                                  ...       ...
# 28657                                                     Released
# 28658                                                     Released
# 28659                                                     Released
# 28660                                                     Released
# 28661  A horror styled, suspenseful thriller, dramati...  Released
#
#                  Director
# 0              Wes Craven
# 1         Taylor Hackford
# 2      Jean-Pierre Jeunet
# 3              Wes Craven
# 4              Luis Llosa
# ...                   ...
# 28657        Mike Chantaj
# 28658   Piotr Matwiejczyk
# 28659                None
# 28660    Matheus Maltempi
# 28661          Sandra Öhl
#
# [28662 rows x 17 columns]

# %%
movies_df
# Out:
#             ID                                    Title Release Date  \
# 0         4232                                   Scream   1996-12-20
# 1         1813                     The Devil's Advocate   1997-10-17
# 2         8078                       Alien Resurrection   1997-11-12
# 3         4233                                 Scream 2   1997-12-12
# 4         9360                                 Anaconda   1997-04-11
# ...        ...                                      ...          ...
# 28657   863593                                   Creaks   2020-06-18
# 28658   823356  Piotrek trzynastego 3: Dziecku rozmaryn   2020-04-22
# 28659   796734                        Rise of the Mummy   2020-04-03
# 28660   700705                 Sometimes She Comes Back   2020-08-05
# 28661  1362981                         Milla: The Movie   2020-10-01
#
#        Popularity  Vote Average  Vote Count    Budget    Revenue  Runtime  \
# 0          81.736         7.421        6838  14000000  173046663      112
# 1          55.402         7.467        5891  57000000  153000000      144
# 2          46.027         6.152        4840  70000000  162000000      109
# 3          43.971         6.493        4074  24000000  172363301      120
# 4          32.929         5.198        2443  45000000  136900000       89
# ...           ...           ...         ...       ...        ...      ...
# 28657       0.001         0.000           0         0          0        5
# 28658       0.001         0.000           0         0          0       83
# 28659       0.001         0.000           0         0          0       87
# 28660       0.001         0.000           0         0          0        7
# 28661       0.000         9.000           1         0          0       98
#
#                                  Genres Original Language  \
# 0                Crime, Horror, Mystery                en
# 1      Drama, Mystery, Thriller, Horror                en
# 2       Science Fiction, Horror, Action                en
# 3                       Horror, Mystery                en
# 4           Adventure, Horror, Thriller                en
# ...                                 ...               ...
# 28657                            Horror                en
# 28658                    Horror, Comedy                pl
# 28659                            Horror                en
# 28660                   Horror, Fantasy                pt
# 28661           Thriller, Drama, Horror                en
#
#                                     Production Companies  \
# 0                   Dimension Films, Woods Entertainment
# 1      Monarchy Enterprises B.V., Regency Enterprises...
# 2               20th Century Fox, Brandywine Productions
# 3      Dimension Films, Konrad Pictures, Craven-Madda...
# 4      St. Tropez Films, Cinema Line Film Corporation...
# ...                                                  ...
# 28657
# 28658  Muflon Pictures, Exd' Art - Obrazy bez granic,...
# 28659
# 28660                             Suco Excêntrico Filmes
# 28661                                             21film
#
#                          Production Countries  \
# 0                    United States of America
# 1           Germany, United States of America
# 2            United States of America, France
# 3                    United States of America
# 4      Brazil, Peru, United States of America
# ...                                       ...
# 28657
# 28658                                  Poland
# 28659
# 28660                                  Brazil
# 28661
#
#                                                 Overview  \
# 0      A year after the murder of her mother, a teena...
# 1      Aspiring Florida defense lawyer Kevin Lomax ac...
# 2      Two hundred years after Lt. Ripley died, a gro...
# 3      Two years after the first series of murders, a...
# 4      A "National Geographic" film crew is taken hos...
# ...                                                  ...
# 28657  Do you still believe in monsters in your close...
# 28658  The third part of the American horror movie pa...
# 28659  A group of friends seize the opportunity to le...
# 28660  Erica tries to distract herself in front of th...
# 28661  "THE WORST NIGHTMARE RESTS WHERE NOT EXPECTED"...
#
#                                                  Tagline    Status  \
# 0      Someone has taken their love of scary movies o...  Released
# 1      The newest attorney at the world's most powerf...  Released
# 2                                 It's already too late.  Released
# 3      Someone has taken their love of sequels one st...  Released
# 4              When you can't breathe, you can't scream.  Released
# ...                                                  ...       ...
# 28657                                                     Released
# 28658                                                     Released
# 28659                                                     Released
# 28660                                                     Released
# 28661  A horror styled, suspenseful thriller, dramati...  Released
#
#                  Director
# 0              Wes Craven
# 1         Taylor Hackford
# 2      Jean-Pierre Jeunet
# 3              Wes Craven
# 4              Luis Llosa
# ...                   ...
# 28657        Mike Chantaj
# 28658   Piotr Matwiejczyk
# 28659                None
# 28660    Matheus Maltempi
# 28661          Sandra Öhl
#
# [28662 rows x 17 columns]

# %%
movies_df.to_csv('TMDB_Horror_Data')
